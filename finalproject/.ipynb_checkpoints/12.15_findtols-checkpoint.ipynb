# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import scipy
import argparse
from RKadaptivemultieq import *
from diffeqs import *
from diffeqs_forscipy import *
from plottingfns import * #still have to update animate to handle varying size time steps
from getICs import *
import sys
import os
sys.path.append(os.path.join('..', 'importantfunctions'))
from ODEsolvers import *

# %% [markdown]
# Turns out this whole exercise was unnecessary because I fixed a small thing in my adaptive code that made it way way faster, so can just use tolerance of 1e-12 for everything.

# %%
R0=getICs('twostars','recommended')
t_span=(0,10)
Ts=np.linspace(t_span[0],t_span[1],10000)
results=scipy.integrate.solve_ivp(twostars_forscipy,t_span=t_span,y0=R0,first_step=1e-6,t_eval=Ts,rtol=1e-6,atol=1e-6)
Rs=results.y.T
colors=getcolors('twostars','plot')
plot(Ts,Rs,colors)
#anything above 1e-5 made the plot look visibly different so going with 1e-6 just in case

# %%
R0=getICs('twostarsandplanet','recommended')
t_span=(0,10)
Ts=np.linspace(t_span[0],t_span[1],10000)
results=scipy.integrate.solve_ivp(twostarsandplanet_forscipy,t_span=t_span,y0=R0,first_step=1e-6,t_eval=Ts,rtol=1e-12,atol=1e-12)
Rs=results.y.T
colors=getcolors('twostarsandplanet','plot')
plot(Ts,Rs,colors)

# %%
R0=getICs('twostarsandplanet','recommended')
t_span=(0,10)
Ts=np.linspace(t_span[0],t_span[1],10000)
results=scipy.integrate.solve_ivp(twostarsandplanet_forscipy,t_span=t_span,y0=R0,first_step=1e-6,t_eval=Ts,rtol=1e-8,atol=1e-8)
Rs=results.y.T
colors=getcolors('twostarsandplanet','plot')
plot(Ts,Rs,colors)
#anything above 1e-7 made the plot look visibly different so going with 1e-8 just in case

# %%
R0=getICs('threestars','recommended')
t_span=(0,10)
Ts=np.linspace(t_span[0],t_span[1],10000)
results=scipy.integrate.solve_ivp(threestars_forscipy,t_span=t_span,y0=R0,first_step=1e-6,t_eval=Ts,rtol=1e-12,atol=1e-12)
Rs=results.y.T
colors=getcolors('threestars','plot')
plot(Ts,Rs,colors)

# %%
R0=getICs('threestars','recommended')
t_span=(0,10)
Ts=np.linspace(t_span[0],t_span[1],10000)
results=scipy.integrate.solve_ivp(threestars_forscipy,t_span=t_span,y0=R0,first_step=1e-6,t_eval=Ts,rtol=1e-8,atol=1e-8)
Rs=results.y.T
colors=getcolors('threestars','plot')
plot(Ts,Rs,colors)

# %%
R0=getICs('oneorbit','recommended')
t_span=(0,10)
Ts=np.linspace(t_span[0],t_span[1],10000)
results=scipy.integrate.solve_ivp(oneorbit_forscipy,t_span=t_span,y0=R0,first_step=1e-6,t_eval=Ts,rtol=1e-6,atol=1e-6)
Rs=results.y.T
colors=getcolors('oneorbit','plot')
plot(Ts,Rs,colors)
